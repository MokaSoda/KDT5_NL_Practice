# %%
import sys
from bareunpy import Tagger

API_KEY="koba-TXPHP7A-AOWEX4Y-WCTFG3I-RFAISLA"

# 방금 설치한 자신의 호스트에 접속합니다.
tagger = Tagger(API_KEY, 'localhost')
# 결과를 가져옵니다.
res = tagger.tags(["안녕하세요.", "바른을 사용해서 새로운 경험을 해보세요."])

# %%
import ujson

ujson.loads(res.as_json_str())
# Out:
# {'sentences': [{'text': {'content': '안녕하세요.', 'length': 6, 'beginOffset': 0},
#    'tokens': [{'text': {'content': '안녕하세요.', 'length': 6, 'beginOffset': 0},
#      'morphemes': [{'text': {'content': '안녕하', 'length': 3, 'beginOffset': 0},
#        'tag': 'VA',
#        'outOfVocab': 'IN_BUILTIN_DICT',
#        'probability': 0.0},
#       {'text': {'content': '시', 'beginOffset': 3, 'length': 1},
#        'tag': 'EP',
#        'probability': 0.99855566,
#        'outOfVocab': 'IN_WORD_EMBEDDING'},
#       {'text': {'content': '어요', 'beginOffset': 3, 'length': 2},
#        'tag': 'EF',
#        'probability': 0.9940101,
#        'outOfVocab': 'IN_WORD_EMBEDDING'},
#       {'text': {'content': '.', 'beginOffset': 5, 'length': 1},
#        'tag': 'SF',
#        'probability': 0.9994902,
#        'outOfVocab': 'IN_WORD_EMBEDDING'}],
#      'lemma': '안녕하',
#      'tagged': '안녕하/VA+시/EP+어요/EF+./SF',
#      'modified': ''}],
#    'refined': '안녕하세요.'},
#   {'text': {'content': '바른을 사용해서 새로운 경험을 해보세요.',
#     'beginOffset': 7,
#     'length': 22},
#    'tokens': [{'text': {'content': '바른을', 'beginOffset': 7, 'length': 3},
#      'morphemes': [{'text': {'content': '바른', 'beginOffset': 7, 'length': 2},
#        'tag': 'NNG',
#        'probability': 0.8229952,
#        'outOfVocab': 'OUT_OF_VOCAB'},
#       {'text': {'content': '을', 'beginOffset': 9, 'length': 1},
#        'tag': 'JKO',
#        'probability': 0.998543,
#        'outOfVocab': 'IN_WORD_EMBEDDING'}],
#      'lemma': '바른',
#      'tagged': '바른/NNG+을/JKO',
#      'modified': ''},
#     {'text': {'content': '사용해서', 'beginOffset': 11, 'length': 4},
#      'morphemes': [{'text': {'content': '사용하', 'beginOffset': 11, 'length': 3},
#        'tag': 'VV',
#        'outOfVocab': 'IN_BUILTIN_DICT',
#        'probability': 0.0},
#       {'text': {'content': '아서', 'beginOffset': 13, 'length': 2},
#        'tag': 'EC',
#        'probability': 0.9911923,
#        'outOfVocab': 'IN_WORD_EMBEDDING'}],
#      'lemma': '사용하',
#      'tagged': '사용하/VV+아서/EC',
#      'modified': ''},
#     {'text': {'content': '새로운', 'beginOffset': 16, 'length': 3},
#      'morphemes': [{'text': {'content': '새롭', 'beginOffset': 16, 'length': 2},
#        'tag': 'VA',
#        'probability': 0.99332476,
#        'outOfVocab': 'IN_WORD_EMBEDDING'},
#       {'text': {'content': 'ㄴ', 'beginOffset': 18, 'length': 1},
#        'tag': 'ETM',
#        'probability': 0.99967784,
#        'outOfVocab': 'IN_WORD_EMBEDDING'}],
#      'lemma': '새롭',
#      'tagged': '새롭/VA+ㄴ/ETM',
#      'modified': ''},
#     {'text': {'content': '경험을', 'beginOffset': 20, 'length': 3},
#      'morphemes': [{'text': {'content': '경험', 'beginOffset': 20, 'length': 2},
#        'tag': 'NNG',
#        'probability': 0.9818059,
#        'outOfVocab': 'IN_WORD_EMBEDDING'},
#       {'text': {'content': '을', 'beginOffset': 22, 'length': 1},
#        'tag': 'JKO',
#        'probability': 0.9997478,
#        'outOfVocab': 'IN_WORD_EMBEDDING'}],
#      'lemma': '경험',
#      'tagged': '경험/NNG+을/JKO',
#      'modified': ''},
#     {'text': {'content': '해보세요.', 'beginOffset': 24, 'length': 5},
#      'morphemes': [{'text': {'content': '해보', 'beginOffset': 24, 'length': 2},
#        'tag': 'VV',
#        'probability': 0.0,
#        'outOfVocab': 'IN_WORD_EMBEDDING'},
#       {'text': {'content': '시', 'beginOffset': 26, 'length': 1},
#        'tag': 'EP',
#        'probability': 0.9998999,
#        'outOfVocab': 'IN_WORD_EMBEDDING'},
#       {'text': {'content': '어요', 'beginOffset': 26, 'length': 2},
#        'tag': 'EF',
#        'probability': 0.9962929,
#        'outOfVocab': 'IN_WORD_EMBEDDING'},
#       {'text': {'content': '.', 'beginOffset': 28, 'length': 1},
#        'tag': 'SF',
#        'probability': 0.9995272,
#        'outOfVocab': 'IN_WORD_EMBEDDING'}],
#      'lemma': '해보',
#      'tagged': '해보/VV+시/EP+어요/EF+./SF',
#      'modified': '해보세요.'}],
#    'refined': '바른을 사용해서 새로운 경험을 해보세요.'}],
#  'language': 'ko_KR'}
